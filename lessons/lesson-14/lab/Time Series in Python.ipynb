# %%
# Import libraries
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
# Read in data
df = pd.read_csv('../../../data/example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# Fit a time series model
m = Prophet()
m.fit(df);
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.5/dist-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
# Predict future time series
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# Attach predicted values - yhat
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206753    7.491787    8.933022
# 3266 2017-01-16  8.531766    7.876318    9.265727
# 3267 2017-01-17  8.319156    7.634427    9.075389
# 3268 2017-01-18  8.151772    7.447157    8.908008
# 3269 2017-01-19  8.163690    7.479991    8.923816

# %%
# Plot the forecasted values
from matplotlib import pyplot as plt
# %matplotlib inline

m.plot(forecast);

# %%
# Time Series Decomposition
m.plot_components(forecast);
